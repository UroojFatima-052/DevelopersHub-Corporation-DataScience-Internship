# %% [markdown]
# # Churn Modelling Dataset - Introduction
#
# Churn Modelling Dataset is a tabular dataset containing bank customer details like geography and gender, used to predict customer churn (leave the bank) and study feature importance for business insights. I have downloaded this dataset from Kaggle to complete Task 2

# %%
import pandas as pd

# %% [markdown]
# ## Loading & Inspecting Dataset

# %%
df = pd.read_csv('vib_churn_dataset_final.csv') # loading the dataset

# %%
df.shape # checking the shape
# Out:
# (66736, 30)

# %%
df.head(10) # viewing first 10 rows
# Out:
#    Customer_number  Client_gender        Age  Staff_VIB     Tenure  SMS  \
# 0                1              0  28.215615          1  19.918800    0
# 1                2              1  28.744430          0   8.076794    1
# 2                3              0  35.406264          0  11.641340    0
# 3                4              1  31.186114          0  22.163064    1
# 4                5              0  42.555118          0  21.800850    0
# 5                6              0  20.461942          0  13.227729    0
# 6                7              1  44.434197          0  14.300110    0
# 7                8              0  48.208734          0   7.889344    1
# 8                9              0  42.836443          0   3.850351    0
# 9               10              0  18.000000          0  18.670069    1
#
#    Verify_method  EB_register_channel  No_Activity_Name  Type_Transactions  \
# 0              1                    0                 1                  7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66736 entries, 0 to 66735
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_number             66736 non-null  int64
#  1   Client_gender               66736 non-null  int64
#  2   Age                         66736 non-null  float64
#  3   Staff_VIB                   66736 non-null  int64
#  4   Tenure                      66736 non-null  float64
#  5   SMS                         66736 non-null  int64
#  6   Verify_method               66736 non-null  int64
#  7   EB_register_channel         66736 non-null  int64
#  8   No_Activity_Name            66736 non-null  int64
#  9   Type_Transactions           66736 non-null  int64
#  10  Total_trans_no              66736 non-null  float64
#  11  Avg_Trans_no_month          66736 non-null  float64
#  12  Avg_Trans_Amount            66736 non-null  float64
# ...

# %%
df.describe()
# Out:
#        Customer_number  Client_gender           Age     Staff_VIB  \
# count     66736.000000   66736.000000  66736.000000  66736.000000
# mean      33368.500000       0.550243     35.155292      0.049059
# std       19265.168119       0.497473      9.588401      0.215993
# min           1.000000       0.000000     18.000000      0.000000
# 25%       16684.750000       0.000000     28.246449      0.000000
# 50%       33368.500000       1.000000     34.973129      0.000000
# 75%       50052.250000       1.000000     41.684999      0.000000
# max       66736.000000       1.000000     75.000000      1.000000
#
#              Tenure           SMS  Verify_method  EB_register_channel  \
# count  66736.000000  66736.000000   66736.000000         66736.000000
# mean      12.241216      0.397911       0.901582             0.795987
# std        7.241866      0.489471       0.539107             0.870892
# min        0.500000      0.000000       0.000000             0.000000
# ...

# %%
df.isnull().sum().sum() # checking the total null values
# Out:
# np.int64(0)

# %% [markdown]
# ## Dropping extra columns

# %%
df.drop(columns=['Customer_number'], inplace=True)

# %%
df.shape
# Out:
# (66736, 29)

# %% [markdown]
# # Saving cleaned Dataset

# %%
df.to_csv('cleaned_churn_dataset.csv', index=False) # saved the cleaned dataset for further use.
