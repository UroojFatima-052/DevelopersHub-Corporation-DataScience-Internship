# %%
import pandas as pd

# %% [markdown]
# ## Loading & Inspecting Dataset

# %%
df = pd.read_csv('vib_churn_dataset_final.csv')

# %%
df.shape

# %%
df.head(10)

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum().sum()

# %% [markdown]
# ## Dropping extra columns

# %%
df.drop(columns=['Customer_number'], inplace=True)

# %%
df.shape

# %% [markdown]
# # Saving cleaned Dataset

# %%
df.to_csv('cleaned_churn_dataset.csv', index=False)
